# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
df = pd.read_csv(r"D:\portfolio\ARcraft\final project\project 4\electric_vehicles_spec_2025.csv")
df
# Out:
#        brand                    model  top_speed_kmh  battery_capacity_kWh  \
# 0     Abarth         500e Convertible            155                  37.8
# 1     Abarth           500e Hatchback            155                  37.8
# 2     Abarth      600e Scorpionissima            200                  50.8
# 3     Abarth             600e Turismo            200                  50.8
# 4     Aiways                       U5            150                  60.0
# ..       ...                      ...            ...                   ...
# 473    Zeekr           7X Premium RWD            210                  71.0
# 474    Zeekr        X Core RWD (MY25)            190                  49.0
# 475    Zeekr  X Long Range RWD (MY25)            190                  65.0
# 476    Zeekr   X Privilege AWD (MY25)            190                  65.0
# 477  firefly                      NaN            150                  41.2
#
# ...

# %%
df.head()
# Out:
#     brand                model  top_speed_kmh  battery_capacity_kWh  \
# 0  Abarth     500e Convertible            155                  37.8
# 1  Abarth       500e Hatchback            155                  37.8
# 2  Abarth  600e Scorpionissima            200                  50.8
# 3  Abarth         600e Turismo            200                  50.8
# 4  Aiways                   U5            150                  60.0
#
#   battery_type  number_of_cells  torque_nm  efficiency_wh_per_km  range_km  \
# 0  Lithium-ion            192.0      235.0                   156       225
# 1  Lithium-ion            192.0      235.0                   149       225
# 2  Lithium-ion            102.0      345.0                   158       280
# 3  Lithium-ion            102.0      345.0                   158       280
# 4  Lithium-ion              NaN      310.0                   156       315
#
#    acceleration_0_100_s  ...  towing_capacity_kg cargo_volume_l  seats  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 478 entries, 0 to 477
# Data columns (total 22 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   brand                      478 non-null    object
#  1   model                      477 non-null    object
#  2   top_speed_kmh              478 non-null    int64
#  3   battery_capacity_kWh       478 non-null    float64
#  4   battery_type               478 non-null    object
#  5   number_of_cells            276 non-null    float64
#  6   torque_nm                  471 non-null    float64
#  7   efficiency_wh_per_km       478 non-null    int64
#  8   range_km                   478 non-null    int64
#  9   acceleration_0_100_s       478 non-null    float64
#  10  fast_charging_power_kw_dc  477 non-null    float64
#  11  fast_charge_port           477 non-null    object
#  12  towing_capacity_kg         452 non-null    float64
# ...

# %%
df.describe()
# Out:
#        top_speed_kmh  battery_capacity_kWh  number_of_cells    torque_nm  \
# count     478.000000            478.000000       276.000000   471.000000
# mean      185.487448             74.043724       485.293478   498.012739
# std        34.252773             20.331058      1210.819733   241.461128
# min       125.000000             21.300000        72.000000   113.000000
# 25%       160.000000             60.000000       150.000000   305.000000
# 50%       180.000000             76.150000       216.000000   430.000000
# 75%       201.000000             90.600000       324.000000   679.000000
# max       325.000000            118.000000      7920.000000  1350.000000
#
#        efficiency_wh_per_km    range_km  acceleration_0_100_s  \
# count            478.000000  478.000000            478.000000
# mean             162.903766  393.179916              6.882636
# std               34.317532  103.287335              2.730696
# ...

# %%
df.isna().sum()
# Out:
# brand                          0
# model                          1
# top_speed_kmh                  0
# battery_capacity_kWh           0
# battery_type                   0
# number_of_cells              202
# torque_nm                      7
# efficiency_wh_per_km           0
# range_km                       0
# acceleration_0_100_s           0
# fast_charging_power_kw_dc      1
# fast_charge_port               1
# towing_capacity_kg            26
# cargo_volume_l                 1
# seats                          0
# drivetrain                     0
# segment                        0
# length_mm                      0
# width_mm                       0
# height_mm                      0
# car_body_type                  0
# source_url                     0
# dtype: int64

# %%
mean_cell_no = df['number_of_cells'].mean()
df['number_of_cells'] = df['number_of_cells'].fillna(df['number_of_cells'].mean())

print(df['number_of_cells'].isnull().sum())
# Out:
# 0

# %%
mean_cell_no = df['torque_nm'].mean()
df['torque_nm'] = df['torque_nm'].fillna(df['torque_nm'].mean())

print(df['torque_nm'].isnull().sum())
# Out:
# 0

# %%
df.isna().sum()
# Out:
# brand                         0
# model                         1
# top_speed_kmh                 0
# battery_capacity_kWh          0
# battery_type                  0
# number_of_cells               0
# torque_nm                     0
# efficiency_wh_per_km          0
# range_km                      0
# acceleration_0_100_s          0
# fast_charging_power_kw_dc     1
# fast_charge_port              1
# towing_capacity_kg           26
# cargo_volume_l                1
# seats                         0
# drivetrain                    0
# segment                       0
# length_mm                     0
# width_mm                      0
# height_mm                     0
# car_body_type                 0
# source_url                    0
# number_of-cells               0
# dtype: int64

# %% [markdown]
# DATA VISUALISATION

# %%
numeric_df = df.select_dtypes(include='number')

corr = numeric_df.corr()

plt.figure(figsize=(10, 8))
sns.heatmap(corr, annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5)
plt.title('Correlation Heatmap of Numeric Features')
plt.xticks(rotation=45)
plt.yticks(rotation=0)
plt.tight_layout()
plt.show()

# %%
sns.scatterplot(data=df, x='acceleration_0_100_s', y='top_speed_kmh')
plt.title('Top Speed vs Acceleration')
plt.xlabel('Acceleration (0–100 km/h in sec)')
plt.ylabel('Top Speed (km/h)')
plt.show()

# %%
def remove_outliers_iqr(df, column):
    q1 = df[column].quantile(0.25)
    q3 = df[column].quantile(0.75)
    IQR = q3 - q1
    lower = q1-1.5*IQR
    upper = q3+1.5*IQR
    return df[(df[column] >= lower) & (df[column] <= upper)]

df_clean = remove_outliers_iqr(df, 'top_speed_kmh')

df_clean = df_clean.reset_index(drop=True)

# %%
sns.scatterplot(data=df, x='top_speed_kmh', y='torque_nm')
plt.title('Top Speed vs Torque')
plt.xlabel('Top Speed')
plt.ylabel('Torque')
plt.show()

# %%
def outlier_removal(df, column):
    q1 = df[column].quantile(0.25)
    q3 = df[column].quantile(0.75)
    IQR = q3 - q1
    lower = q1-1.5*IQR
    upper = q3+1.5*IQR
    return df[(df[column] >= lower) & (df[column] <= upper)]
df_clean = remove_outliers_iqr(df, 'torque_nm')
df_clean = df_clean.reset_index(drop=True)

# %%
output_path = r'D:\portfolio\ARcraft\final project\project 4\data\processed\ev_cleaned.csv'
df_clean.to_csv(output_path, index=False)
